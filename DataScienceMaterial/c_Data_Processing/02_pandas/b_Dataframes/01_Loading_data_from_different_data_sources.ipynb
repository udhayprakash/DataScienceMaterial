# %%
import pandas as pd

# %% [markdown]
# To List all the datasets, which we have

# %%
import os

from pathlib import Path

DATASETS_PATH = Path("../../../../datasets/")
os.listdir(DATASETS_PATH)
# Out:
# ['customer.csv',
#  'customers.csv',
#  'IMDB_Movie.csv',
#  'IMDB_Movie.html',
#  'IMDB_Movie.json',
#  'IMDB_Movie.xlsx',
#  'IMDB_Movie_3columns.html',
#  'IMDB_Movie_3columns.json',
#  'IMDB_Movie_3columns.xls',
#  'IMDB_Movie_3columns_without_index.csv',
#  'IMDB_Movie_3columns_with_index.csv',
#  'IMDB_Movie_Apply.csv',
#  'imdb_movie_cleanup.csv',
#  'IMDB_Movie_Facebook_Like.csv',
#  'IMDB_Movie_Filter.csv',
#  'IMDB_Movie_Overview.csv',
#  'IMDB_Movie_Sorting.csv',
#  'Titanic_Disaster.csv',
#  'unused']

# %% [markdown]
# ### 1. loading data from csv

# %%
import pandas as pd
from io import StringIO

csv = r"""dummy,date,loc,x
bar,20090101,a,1
bar,20090102,a,3
bar,20090103,a,5
bar,20090101,b,1
bar,20090102,b,3
bar,20090103,b,5"""

df = pd.read_csv(
    StringIO(csv),
    header=0,
    index_col=["date", "loc"],
    usecols=["date", "loc", "x"],
    parse_dates=["date"],
)

df
# Out:
#                 x
# date       loc
# 2009-01-01 a    1
# 2009-01-02 a    3
# 2009-01-03 a    5
# 2009-01-01 b    1
# 2009-01-02 b    3
# 2009-01-03 b    5

# %%
df_csv = pd.read_csv(Path(DATASETS_PATH / "IMDB_Movie.csv"))
df_csv.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration
# 0  Color      James Cameron                   723.0     178.0  \
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name
# 0                      0.0                   855.0  Joel David Moore  \
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...  \
# ...

# %%
df_csv2 = pd.read_csv(
    "https://vincentarelbundock.github.io/Rdatasets/csv/boot/amis.csv"
)
df_csv2.head()
# Out:
#    Unnamed: 0  speed  period  warning  pair
# 0           1     26       1        1     1
# 1           2     26       1        1     1
# 2           3     26       1        1     1
# 3           4     26       1        1     1
# 4           5     27       1        1     1

# %%
df_diabetes = pd.read_csv(
    "https://raw.githubusercontent.com/martinbel/datasets/master/diabetes.csv"
)

df_diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0              6      148             72             35        0  33.6  \
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ### 2. loading data from excel
#     - user could choose sheet number incase excel file contain multiple sheet

# %%
! pip install -U xlrd --user

# %%
df_excel = pd.read_excel(Path(DATASETS_PATH / "IMDB_Movie.xlsx"), sheet_name=0)
df_excel
# Out:
#                                  movie_title   director_name  title_year
# 0                                    Avatar    James Cameron        2009
# 1  Pirates of the Caribbean: At World's End   Gore Verbinski        2007
# 2                                   Spectre       Sam Mendes        2015

# %% [markdown]
# ### 3. loading data from json

# %%
df_json = pd.read_json(Path(DATASETS_PATH / "IMDB_Movie.json"))
df_json.head()
# Out:
#                                 movie_title   director_name  title_year
# 0                                    Avatar   James Cameron        2009
# 1  Pirates of the Caribbean: At World's End  Gore Verbinski        2007
# 2                                   Spectre      Sam Mendes        2015

# %% [markdown]
# ### 4. loading data from a table on html web page
#     - note that read_html return a list of data table, so to access one talbe need to have table index

# %%
df_html = pd.read_html(Path(DATASETS_PATH / "IMDB_Movie.html"))
df_html[0].head()
# Out:
#    Unnamed: 0                               movie_title   director_name
# 0           0                                    Avatar   James Cameron  \
# 1           1  Pirates of the Caribbean: At World's End  Gore Verbinski
# 2           2                                   Spectre      Sam Mendes
#
#    title_year
# 0      2009.0
# 1      2007.0
# 2      2015.0

# %%
df_html
# Out:
# [   Unnamed: 0                               movie_title   director_name
#  0           0                                    Avatar   James Cameron  \
#  1           1  Pirates of the Caribbean: At World's End  Gore Verbinski
#  2           2                                   Spectre      Sam Mendes
#
#     title_year
#  0      2009.0
#  1      2007.0
#  2      2015.0  ]

# %% [markdown]
# ### 5. loading from a python dictionary
#     - key become columns name
#     - value become row data

# %%
studentData = {
    "name": ["jack", "Riti", "Aadi"],
    "age": [34, 30, 16],
    "city": ["Sydney", "Delhi", "New york"],
}

df_dic = pd.DataFrame(studentData)
df_dic
# Out:
#    name  age      city
# 0  jack   34    Sydney
# 1  Riti   30     Delhi
# 2  Aadi   16  New york

# %% [markdown]
# ### 6. loading from a python class instance

# %%
class Company:
    def __init__(self, name, addr, comp_val):
        self.name = name
        self.addr = addr
        self.__comp_val = comp_val

    def to_dict(self):
        return {"name": self.name, "addr": self.addr, "comp_val": self.__comp_val}


# instantiation
c1 = Company("apple", "addr1", 1111)
c2 = Company("microsoft", "addr2", 2222)
c3 = Company("tesla", "addr3", 3333)

df = pd.DataFrame([inst.to_dict() for inst in [c1, c2, c3]])
print(df)
# Out:
#         name   addr  comp_val
# 0      apple  addr1      1111
# 1  microsoft  addr2      2222
# 2      tesla  addr3      3333

# %% [markdown]
# ### 7. loading data from coinmarketcap

# %%
df_cmc = pd.read_html("http://coinmarketcap.com")
df_cmc
# Out:
# [    Unnamed: 0    #                      Name       Price   1h %  24h %
#  0          NaN  1.0               Bitcoin1BTC  $27,774.48  0.04%  1.15%  \
#  1          NaN  2.0              Ethereum2ETH   $1,806.89  0.10%  0.96%
#  2          NaN  3.0               Tether3USDT     $0.9999  0.00%  0.00%
#  3          NaN  4.0                   BNB4BNB     $309.25  0.11%  1.30%
#  4          NaN  5.0             USD Coin5USDC     $0.9997  0.00%  0.01%
#  ..         ...  ...                       ...         ...    ...    ...
#  95         NaN  NaN                Fei USDFEI       $0.97    NaN    NaN
#  96         NaN  NaN  Basic Attention TokenBAT       $0.27    NaN    NaN
#  97         NaN  NaN             Enjin CoinENJ       $0.40    NaN    NaN
#  98         NaN  NaN                  KavaKAVA       $0.84    NaN    NaN
#  99         NaN  NaN                  dYdXDYDX       $2.47    NaN    NaN
#
#       7d %                Market Cap                         Volume(24h)
# ...

# %%
len(df_cmc)
# Out:
# 1

# %%
df_cmc[0]
# Out:
#     Unnamed: 0    #                      Name       Price   1h %  24h %
# 0          NaN  1.0               Bitcoin1BTC  $27,774.48  0.04%  1.15%  \
# 1          NaN  2.0              Ethereum2ETH   $1,806.89  0.10%  0.96%
# 2          NaN  3.0               Tether3USDT     $0.9999  0.00%  0.00%
# 3          NaN  4.0                   BNB4BNB     $309.25  0.11%  1.30%
# 4          NaN  5.0             USD Coin5USDC     $0.9997  0.00%  0.01%
# ..         ...  ...                       ...         ...    ...    ...
# 95         NaN  NaN                Fei USDFEI       $0.97    NaN    NaN
# 96         NaN  NaN  Basic Attention TokenBAT       $0.27    NaN    NaN
# 97         NaN  NaN             Enjin CoinENJ       $0.40    NaN    NaN
# 98         NaN  NaN                  KavaKAVA       $0.84    NaN    NaN
# 99         NaN  NaN                  dYdXDYDX       $2.47    NaN    NaN
#
#      7d %                Market Cap                         Volume(24h)
# ...

# %%
df_cmc_table = df_cmc[0][
    ["Name", "Market Cap", "Price", "Volume(24h)", "Circulating Supply"]
]
df_cmc_table.head(3)
# Out:
#            Name                Market Cap       Price
# 0   Bitcoin1BTC  $536.85B$536,849,439,450  $27,774.48  \
# 1  Ethereum2ETH  $217.74B$217,743,742,614   $1,806.89
# 2   Tether3USDT    $79.91B$79,908,270,162     $0.9999
#
#                           Volume(24h)   Circulating Supply
# 0          $19,738,231,606710,936 BTC       19,336,356 BTC
# 1         $9,738,888,5995,387,640 ETH      120,457,776 ETH
# 2  $34,297,987,45234,298,161,563 USDT  79,908,675,809 USDT

# %% [markdown]
# ### 8. Reading from tabular data file - csv, excel, tsv, .. table-like data format
#
# read_table assumptions:
# - file is separated by tabs
# - presence of a header role

# %%
# reading a well-formatted .tsv file
url = "http://bit.ly/chiporders"
orders = pd.read_table(url)

orders.head()
# Out:
#    order_id  quantity                              item_name
# 0         1         1           Chips and Fresh Tomato Salsa  \
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
url2 = "http://bit.ly/movieusers"
users = pd.read_table(url2)

users.head()
# Out:
#    1|24|M|technician|85711
# 0       2|53|F|other|94043
# 1      3|23|M|writer|32067
# 2  4|24|M|technician|43537
# 3       5|33|F|other|15213
# 4   6|42|M|executive|98101

# %%
user_cols = ["user_id", "age", "gender", "occupation", "zip_code"]
users = pd.read_table(url2, sep="|", header=None, names=user_cols)

users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# __NOTE:__
#
#         when loading large dataset with python dataframe, the best practices are
#         a. To load in chucks
#         b. filter out unwanted columns
#         c. optimizing the memory usage with using astype() for the columns
#         d. from pandas 1.4, Arrow Library can help in CSV parsing
#                 df = pd.read_csv("largefile.csv", engine="pyarrow")
#
#
#         when loading large dataset with python dataframe, the best practices are
#             a. To load in chucks
#             b. filter out unwanted columns
#             c. optimizing the memory usage with using astype() for the columns
